# %% [markdown]
# # Cloud MongoDB + Folium
#
#
# Load the shipwrecks data and plot in a map

# %%
# Install
# !pip install pymongo
# !pip install dnspython
# !pip install pymongo[srv]
# !pip install folium

# %%
# Imports
import pymongo
import pprint
import urllib.parse
import uuid
import pandas as pd
import folium

# %%
# Load the client
client = pymongo.MongoClient("mongodb+srv://dbuser:dbpassword@cluster0-tdmr9.mongodb.net/test?retryWrites=true&w=majority")

# Load the database
database = client['sample_geospatial']

# Load a collection
shipwrecks = database['shipwrecks']

# Load a instance of Shipwrecks (Don't use all)
instances = shipwrecks.find().sort("_id",pymongo.DESCENDING)[:1000]

# %%
# Build a dataframe using the instances
dataframe = pd.DataFrame(instances)

dataframe.head()
# Out:
#                         _id recrd vesslterms  \
# 0  578f6fa3df35c7fbdbaf041a
# 1  578f6fa3df35c7fbdbaf0419
# 2  578f6fa3df35c7fbdbaf0418
# 3  578f6fa3df35c7fbdbaf0417
# 4  578f6fa3df35c7fbdbaf0416
#
#                        feature_type                         chart     latdec  \
# 0  Wrecks - Submerged, nondangerous         US,US,reprt,L-1185/07  14.375000
# 1  Wrecks - Submerged, nondangerous  US,US,reprt,8thCGD,LNM 51/06  26.815334
# 2                  Wrecks - Visible          US,U1,reprt,WN 14/12  22.448397
# 3  Wrecks - Submerged, nondangerous         US,US,graph,Chart 411  26.311493
# 4     Wrecks - Submerged, dangerous         US,US,graph,Chart 411  20.770311
#
#        londec gp_quality   depth sounding_type history             quasou  \
# 0 -170.658333             1828.8                        least depth known
# 1  -90.586395                                               depth unknown
# 2  -89.598419
# ...

# %%
map_instance = folium.Map(zoom_start=13)

ships = 0
for index, row in dataframe.iterrows():
    latdec = row['latdec']
    londec = row['londec']
    folium.map.Marker([latdec, londec]).add_to(map_instance)    
    #print('lat:', latdec, ' lon:', londec)
    ships += 1

map_instance.add_child(folium.LatLngPopup())

print("Number of points:", ships)
# Out:
# Number of points: 1000

# %%
map_instance
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#map_instance.save('map_shipwrecks.html')
